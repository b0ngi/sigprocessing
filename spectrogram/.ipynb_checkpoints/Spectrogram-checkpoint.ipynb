# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read, write

from IPython.display import Audio
from numpy.fft import fft, ifft
# %matplotlib inline

# %% [markdown]
# ## Read Audio Input "Neural Network"

# %% [markdown]
# You can use scipy.io.wavefile to read and write a wav file.
# Usually audio file contains two channels (left and right). We will only keep one channel for simplicity. In the code below, "data = data[:,0]" will keep channel 0.
#
# The duration of the audio can be calculated as:
#
# $time_{length}=N/F_s$
# - Where N is the number of samples
# - F_s is the sampling rate

# %%
Fs_NN0, data_NN0 = read('./audios/Neural_Networks_0.wav')
data_NN0=data_NN0[:,0]
N=len(data_NN0)
t_length=N/Fs_NN0
time=np.linspace(0,t_length,N)
# Plot the wave
plt.figure()
plt.plot(time,data_NN0)
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('Waveform of Test Audio')
plt.show()
#Play the audio with  IPython.display.Audio
Audio(data_NN0, rate=Fs_NN0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Get the spectrum

# %%
# for opening the media file
import scipy.io.wavfile as wavfile

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(data_NN0, Fs=Fs_NN0)
plt.show()
# Out:
# /home/c7031297/Pyrep_env/lib/python3.6/site-packages/matplotlib/axes/_axes.py:7544: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# # Remove deadzones

# %%
Fs_NN0, data_NN0 = read('./audios/Neural_Networks_0.wav')

data_NN0=data_NN0[30000:-30000,0]

#Get the time vector
N=len(data_NN0)
t_length=N/Fs_NN0
time=np.linspace(0,t_length,N)

# Plot the wave
plt.figure()
plt.plot(time,data_NN0)
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('Waveform of Test Audio')
plt.show()
#Play the audio with  IPython.display.Audio
Audio(data_NN0, rate=Fs_NN0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Get the spectrum new signal

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2,figsize=(10, 8))
ax1.plot(time,data_NN0)

NFFT = 256  # the length of the windowing segments
powerSpectrum, frequenciesFound, time, imageAxis = ax2.specgram( data_NN0, NFFT=NFFT, Fs=Fs_NN0, noverlap=128)
# The `specgram` method returns 4 objects. They are:
# - Pxx: the periodogram
# - freqs: the frequency vector
# - bins: the centers of the time bins
# - im: the matplotlib.image.AxesImage instance representing the data in the plot

plt.show()

# %% [markdown]
# # AUDIO_2: "Computer Science"

# %%
Fs_CS0, data_CS0 = read('./audios/computer_science_0.wav')
data_CS0=data_CS0[42000:-30000,0]
# Plot the wave
plt.figure()
plt.plot(data_CS0)
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('Waveform of Test Audio')
plt.show()
#Play the audio with  IPython.display.Audio
Audio(data_CS0, rate=Fs_CS0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# for opening the media file
import scipy.io.wavfile as wavfile

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(data_CS0, Fs=Fs_CS0)
plt.show()

# %% [markdown]
# # AUDIO_2_0: "COMPUTER SCIENCE"

# %%
Fs_CS1, data_CS1 = read('./audios/computer_science_1.wav')
data_CS1=data_CS1[43000:-30000,0]
# Plot the wave
plt.figure()
plt.plot(data_CS1)
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('Waveform of Test Audio')
plt.show()
#Play the audio with  IPython.display.Audio
Audio(data_CS1, rate=Fs_CS1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# for opening the media file
import scipy.io.wavfile as wavfile

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(data_CS1, Fs=Fs_CS1)
plt.show()

# %% [markdown]
# # AUDIO_3: "Glühwein"

# %%
Fs_GW0, data_GW0 = read('./audios/Glühwein.wav')
data_GW0=data_GW0[40000:-30000,0]
# Plot the wave
plt.figure()
plt.plot(data_GW0)
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('Waveform of Test Audio')
plt.show()
#Play the audio with  IPython.display.Audio
Audio(data_GW0, rate=Fs_GW0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# for opening the media file
import scipy.io.wavfile as wavfile

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(data_GW0, Fs=Fs_GW0)


plt.show()

# %%
fig, axs = plt.subplots(3,figsize=(8, 8))
fig.suptitle('Vertically stacked subplots')
#Neural Networks audio
axs[0].specgram(data_NN0, Fs=Fs_NN0);
#Computer Science audio
axs[1].specgram(data_CS0, Fs=Fs_CS0);
#Glühwein audio
axs[2].specgram(data_GW0, Fs=Fs_GW0);

# %%
from PIL import Image


powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(data_GW0, Fs=Fs_GW0)



#Save the image
plt.savefig('./spectoogram.png')
#Convert the image into grayscale
img = Image.open('spectoogram.png').convert('L')
img.save('./greyscale.png')
#Resize
image = Image.open('./greyscale.png')
print("Original size=",image.size) 
new_image = image.resize((435, 300))
new_image.save('./image_400.jpg')
print("New size=",new_image.size)
# Out:
# Original size= (432, 288)
# New size= (435, 300)
